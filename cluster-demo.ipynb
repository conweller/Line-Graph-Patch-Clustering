# %%
from main import *
windowh, windoww = WINDOW_SIZE

# %%
test_img_1 = open_img("line-test-1.jpg", size=(windoww, windowh))
plt.imshow(test_img_1)

# %%
test_features_1 = get_features(test_img_1)
[test_label_1] = km_model.predict([test_features_1])

# %%
show_cluster(km_model, test_label_1)

# %%
test_img_2 = open_img("line-test-2.jpg", size=(windoww, windowh))
plt.imshow(test_img_2)

# %%
test_features_2 = get_features(test_img_2)
[test_label_2] = km_model.predict([test_features_2])

# %%
show_cluster(km_model, test_label_2)

# %%
test_img_3 = open_img("line-test-3.jpg", size=(windoww, windowh))
plt.imshow(test_img_3)

# %%
test_features_3 = get_features(test_img_3)
[test_label_3] = km_model.predict([test_features_3])

# %%
show_cluster(km_model, test_label_3)
